# %% [markdown]
# # Analysis of Agent Performance

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Graphs

# %%
data = pd.read_csv("./client/rl_out/progress.csv")
plt.figure()
sns.lineplot(data=data, x="time/iterations", y="rollout/ep_rew_mean")
plt.figure()
sns.lineplot(data=data, x="time/iterations", y="rollout/ep_len_mean")
plt.figure()
sns.lineplot(data=data, x="time/iterations", y="train/loss")
plt.figure()
sns.lineplot(data=data, x="time/iterations", y="train/policy_gradient_loss")
plt.figure()
sns.lineplot(data=data, x="time/iterations", y="train/value_loss")
# Out:
# <Axes: xlabel='time/iterations', ylabel='train/value_loss'>
